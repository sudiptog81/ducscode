# %% [markdown]
# # Problem Set 4.5

# %% [markdown]
# ### Question 31

# %%
WolframAlpha["limit of (sqrt(x^2 - x) - x) as x tends to infinity", PodStates -> {"Limit__Step-by-step solution"}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %% [markdown]
# ### Question 32

# %%
WolframAlpha["limit of (x - ln(exp(x) + exp(-x))) as x tends to infinity", PodStates -> {"Limit__Step-by-step solution"}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %% [markdown]
# ### Question 33

# %%
WolframAlpha["limit of (x - ln(exp(x) + exp(-x))) as x tends to infinity", PodStates -> {"Limit__Step-by-step solution"}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %% [markdown]
# ### Question 34

# %%
WolframAlpha["limit of ((1/(x^2)) - ln(sqrt(x))) as x tends to 0+", PodStates -> {"Limit__Step-by-step solution"}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %% [markdown]
# ### Question 40

# %%
WolframAlpha["limit of ((2cos(x)/sin(2x)) - (1/x)) as x tends to 0+", PodStates -> {"Limit__Step-by-step solution"}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>
